# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df1 = pd.read_csv('df1')
df2 = pd.read_csv('df2')

# %%
plt.style.use('classic')

# %%
df1.head()
# Out:
#    Unnamed: 0         A         B         C         D
# 0  2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 1  2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2  2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 3  2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 4  2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df1.set_index('Unnamed: 0',inplace=True)
df1
# Out:
#                    A         B         C         D
# Unnamed: 0
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436
# ...              ...       ...       ...       ...
# 2002-09-22  1.013897 -0.288680 -0.342295 -0.638537
# 2002-09-23 -0.642659 -0.104725 -0.631829 -0.909483
# 2002-09-24  0.370136  0.233219  0.535897 -1.552605
# 2002-09-25  0.183339  1.285783 -1.052593 -2.565844
# 2002-09-26  0.775133 -0.850374  0.486728 -1.053427
#
# [1000 rows x 4 columns]

# %%
df2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %% [markdown]
# - Plotar um histograma
# - é possivel alterar estilo usando plt.style.use()

# %%
df1['A'].hist()

# %%
df2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %%
df2.plot.area(alpha=0.7)

# %%
df2.plot.bar()

# %%
df2.plot.bar(stacked=True)

# %% [markdown]
# - Utilizando o plot em histograma para analisar a frequencia de dados de uma unica coluna

# %%
df1['A'].plot.hist(bins=50)

# %%
df1.plot.line(y='B',figsize=(12,3),lw=1)

# %%
df1.plot.scatter(x='A',y='B')

# %% [markdown]
# - O parametro c relaciona um novo dado ao grafico, ele colore as bolinhas de A e B conforme esses dados se relacionam com o C

# %%
df1.plot.scatter(x='A',y='B',c='C',cmap='coolwarm')

# %% [markdown]
# - O parametro s, altera o tamanho dos pontos comforme ocorre a relação

# %%
df1.plot.scatter(x='A',y='B',s=df1['C']*30)

# %% [markdown]
# - É possível fazer também o boxplot

# %%
df2.plot.box()

# %%
df = pd.DataFrame(np.random.rand(1000,2),columns=['A','B'])
df
# Out:
#             A         B
# 0    0.767769  0.532256
# 1    0.086879  0.816548
# 2    0.169741  0.303283
# 3    0.712091  0.670370
# 4    0.094649  0.747413
# ..        ...       ...
# 995  0.499343  0.215558
# 996  0.440900  0.418315
# 997  0.353050  0.634253
# 998  0.005522  0.472030
# 999  0.329977  0.719666
#
# [1000 rows x 2 columns]

# %% [markdown]
# - grafico hexagonal

# %%
df.plot.hexbin(x='A',y='B',gridsize=20,cmap='coolwarm')

# %%
df2['a'].plot.kde(lw=2)

# %%
df2.plot.kde(lw=2)
