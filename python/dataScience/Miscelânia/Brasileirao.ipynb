# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
dfbr = pd.read_csv('campeoes_brasileiro.csv')

# %%
dfbr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 63 entries, 0 to 62
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Ano                63 non-null     int64
#  1   Vencedor           63 non-null     object
#  2   Vice               63 non-null     object
#  3   Terceiro colocado  63 non-null     object
#  4   Quarto colocado    63 non-null     object
#  5   Artilheiro(s)      63 non-null     object
#  6   Gols               63 non-null     int64
# dtypes: int64(2), object(5)
# memory usage: 3.6+ KB

# %%
dfbr.head()
# Out:
#     Ano   Vencedor       Vice Terceiro colocado Quarto colocado  \
# 0  1959      Bahia     Santos            Grêmio   Vasco da Gama
# 1  1960  Palmeiras  Fortaleza        Fluminense      Santa Cruz
# 2  1961     Santos      Bahia           America         Náutico
# 3  1962     Santos   Botafogo     Internacional           Sport
# 4  1963     Santos      Bahia            Grêmio        Botafogo
#
#          Artilheiro(s)  Gols
# 0  Léo Briglia (Bahia)     8
# 1   Bececê (Fortaleza)     7
# 2        Pelé (Santos)     7
# 3    Coutinho (Santos)     7
# 4        Pelé (Santos)     8

# %%
dfbr[dfbr['Ano']==2018]
# Out:
#      Ano   Vencedor      Vice Terceiro colocado Quarto colocado  \
# 61  2018  Palmeiras  Flamengo     Internacional          Grêmio
#
#        Artilheiro(s)  Gols
# 61  Gabriel (Santos)    18

# %%
dfbr['Artilheiro(s)'].value_counts()
# Out:
# Pelé (Santos)                                                                   3
# Zico (Flamengo)                                                                 2
# Romário (Vasco da Gama)                                                         2
# Roberto Dinamite (Vasco da Gama)                                                2
# Fred (Fluminense)                                                               2
# Washington (Atlético Paranaense)                                                1
# Henrique Dourado (Fluminense)   Jô (Corinthians)                                1
# Dimba (Goiás)                                                                   1
# Edmundo (Vasco da Gama)                                                         1
# Dario (Internacional)                                                           1
# Ricardo Oliveira (Santos)                                                       1
# ...

# %%
plt.figure(figsize=(20,6))
dfbr['Vice'].value_counts().plot()

# %%
dfbr[dfbr['Vencedor']=='Flamengo']['Artilheiro(s)'].value_counts()
# Out:
# Zico (Flamengo)                                         2
# Bebeto (Vasco da Gama)                                  1
# Gabriel (Flamengo)                                      1
# Serginho Chulapa (Santos)                               1
# Adriano (Flamengo) Diego Tardelli (Atlético Mineiro)    1
# Name: Artilheiro(s), dtype: int64

# %%
plt.figure(figsize=(20,6))
sns.countplot(data=dfbr,x=dfbr['Vencedor'])

# %%
df2 = pd.read_csv('campeonato-brasileiro.csv')

# %%
df2.head()
# Out:
#   Horário      Dia        Data      Clube 1      Clube 2    Vencedor  \
# 0   16h00   Sábado  2000-07-29   Fluminense        Bahia  Fluminense
# 1   16h00   Sábado  2000-07-29        Vasco        Sport       Sport
# 2   16h00   Sábado  2000-07-29      Vitória    Palmeiras     Vitória
# 3   17h00  Domingo  2000-07-30  Botafogo-RJ  Atlético-MG           -
# 4   18h30  Domingo  2000-07-30    Juventude     Flamengo           -
#
#       Rodada           Arena  Clube 1 Gols  Clube 2 Gols Clube 1 Estado  \
# 0  1ª Rodada        Maracanã             2             0             RJ
# 1  1ª Rodada    São Januário             0             2             RJ
# 2  1ª Rodada        Barradão             4             1             ES
# 3  1ª Rodada    Caio Martins             0             0             RJ
# 4  1ª Rodada  Alfredo Jaconi             1             1             RS
#
#   Clube 2 Estado Estado Clube Vencedor
# 0             BA                    RJ
# ...

# %%
df2[df2['Vencedor']=='Flamengo']['Dia'].value_counts()
# Out:
# Domingo          144
# Sábado            66
# Quarta-feira      50
# Quinta-feira      33
# Sexta-feira        2
# Segunda-feira      2
# Terça-feira        1
# Name: Dia, dtype: int64

# %%
type(df2['Data'].iloc[2])
# Out:
# str

# %%
df2['Data'] = df2['Data'].apply(lambda x: pd.to_datetime(x))

# %%
type(df2['Data'].iloc[2])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
df2['Data']
# Out:
# 0      2000-07-29
# 1      2000-07-29
# 2      2000-07-29
# 3      2000-07-30
# 4      2000-07-30
#           ...
# 7934   2019-12-08
# 7935   2019-12-08
# 7936   2019-12-08
# 7937   2019-12-08
# 7938   2019-12-08
# Name: Data, Length: 7939, dtype: datetime64[ns]

# %%
df2[df2['Data'].dt.year == 2019]['Vencedor'].value_counts()
# Out:
# -                98
# Flamengo         28
# Santos           22
# Palmeiras        21
# Grêmio           19
# Athlético-PR     18
# São Paulo        17
# Internacional    16
# Fortaleza        15
# Goiás            15
# Corinthians      14
# Atlético-MG      13
# Botafogo-rj      13
# Bahia            12
# Vasco            12
# Fluminense       12
# Ceará            10
# CSA               8
# Chapecoense       7
# Cruzeiro          7
# Avaí              3
# Name: Vencedor, dtype: int64

# %%
plt.figure(figsize=(20,6))
sns.countplot(data=df2,x=df2[df2['Data'].dt.year == 2019]['Vencedor'])

# %%
teste = df2[df2['Data'].dt.year == 2019]

# %%
teste[teste['Estado Clube Vencedor'] == 'Empate']
# Out:
#      Horário           Dia       Data      Clube 1       Clube 2 Vencedor  \
# 7569   19:15  Quarta-feira 2019-05-01         Avaí        Grêmio        -
# 7570   16:00  Quarta-feira 2019-05-01          CSA     Palmeiras        -
# 7579   19:00        Sábado 2019-05-04        Vasco   Corinthians        -
# 7582   11:00       Domingo 2019-05-05  Chapecoense  Athlético-PR        -
# 7583   16:00       Domingo 2019-05-05    São Paulo      Flamengo        -
# ...      ...           ...        ...          ...           ...      ...
# 7919   22:30  Quarta-feira 2019-12-04   Fluminense     Fortaleza        -
# 7925   20:15  Quinta-feira 2019-12-05        Bahia         Vasco        -
# 7929   17:00       Domingo 2019-12-08         Avaí  Athlético-PR        -
# 7930   17:00       Domingo 2019-12-08  Botafogo-rj         Ceará        -
# 7931   17:00       Domingo 2019-12-08        Vasco   Chapecoense        -
#
#           Rodada              Arena  Clube 1 Gols  Clube 2 Gols  \
# ...

# %%
teste.dropna().head(20)
# Out:
#      Horário           Dia       Data        Clube 1        Clube 2  \
# 7559   19:00        Sábado 2019-04-27    Atlético-MG           Avaí
# 7560   19:00        Sábado 2019-04-27    Chapecoense  Internacional
# 7561   21:00        Sábado 2019-04-27       Flamengo       Cruzeiro
# 7562   16:00        Sábado 2019-04-27      São Paulo    Botafogo-rj
# 7563   16:00       Domingo 2019-04-28   Athlético-PR          Vasco
# 7564   16:00       Domingo 2019-04-28          Bahia    Corinthians
# 7565   16:00       Domingo 2019-04-28          Ceará            CSA
# 7566   19:00       Domingo 2019-04-28     Fluminense          Goiás
# 7567   19:00       Domingo 2019-04-28      Palmeiras      Fortaleza
# 7568   11:00       Domingo 2019-04-28         Grêmio         Santos
# 7569   19:15  Quarta-feira 2019-05-01           Avaí         Grêmio
# 7570   16:00  Quarta-feira 2019-05-01            CSA      Palmeiras
# 7571   21:30  Quarta-feira 2019-05-01          Vasco    Atlético-MG
# ...
